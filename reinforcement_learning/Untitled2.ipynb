# %%
from env.bidding_env import BiddingEnv
# Out:
# Loaded lib <CDLL './libdds.so', handle 55cee3e2bad0 at 0x7ff96c6807b8>

# %%
from baselines import deepq

# %%
model = deepq.models.mlp([64])
env = BiddingEnv()
act = deepq.learn(
        env,
        q_func=model,
        lr=1e-3,
        max_timesteps=100000,
        buffer_size=50000,
        exploration_fraction=0.1,
        exploration_final_eps=0.02,
        print_freq=10,
        callback=None
    )
# Out:
# WARNING:tensorflow:From /home/vagrant/.venv/ml4/lib/python3.6/site-packages/tensorflow/python/ops/clip_ops.py:113: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 10       |
# | mean 100 episode reward | -9       |
# | steps                   | 17       |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 20       |
# | mean 100 episode reward | -9       |
# | steps                   | 37       |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 30       |
# | mean 100 episode reward | -9       |
# | steps                   | 57       |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 40       |
# | mean 100 episode reward | -9       |
# | steps                   | 77       |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 50       |
# | mean 100 episode reward | -9       |
# | steps                   | 97       |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 60       |
# | mean 100 episode reward | -9       |
# | steps                   | 117      |
# --------------------------------------
# /home/vagrant/.venv/ml4/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/vagrant/.venv/ml4/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 70       |
# | mean 100 episode reward | -9       |
# | steps                   | 137      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 80       |
# | mean 100 episode reward | -9       |
# | steps                   | 157      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 90       |
# | mean 100 episode reward | -9       |
# | steps                   | 177      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 100      |
# | mean 100 episode reward | -9       |
# | steps                   | 197      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 110      |
# | mean 100 episode reward | -9       |
# | steps                   | 217      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 120      |
# | mean 100 episode reward | -9       |
# | steps                   | 237      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 130      |
# | mean 100 episode reward | -9       |
# | steps                   | 257      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 140      |
# | mean 100 episode reward | -9       |
# | steps                   | 277      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 150      |
# | mean 100 episode reward | -9       |
# | steps                   | 297      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 160      |
# | mean 100 episode reward | -9       |
# | steps                   | 317      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 170      |
# | mean 100 episode reward | -9       |
# | steps                   | 337      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 180      |
# | mean 100 episode reward | -9       |
# | steps                   | 357      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 190      |
# | mean 100 episode reward | -9       |
# | steps                   | 377      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 200      |
# | mean 100 episode reward | -9       |
# | steps                   | 397      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 210      |
# | mean 100 episode reward | -9       |
# | steps                   | 417      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 220      |
# | mean 100 episode reward | -9       |
# | steps                   | 437      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 230      |
# | mean 100 episode reward | -9       |
# | steps                   | 457      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 240      |
# | mean 100 episode reward | -9       |
# | steps                   | 477      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 250      |
# | mean 100 episode reward | -9       |
# | steps                   | 497      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 260      |
# | mean 100 episode reward | -9       |
# | steps                   | 517      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 270      |
# | mean 100 episode reward | -9       |
# | steps                   | 537      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 280      |
# | mean 100 episode reward | -9       |
# | steps                   | 557      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 290      |
# | mean 100 episode reward | -9       |
# | steps                   | 577      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 300      |
# | mean 100 episode reward | -9       |
# | steps                   | 597      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 310      |
# | mean 100 episode reward | -9       |
# | steps                   | 617      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 320      |
# | mean 100 episode reward | -9       |
# | steps                   | 637      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 330      |
# | mean 100 episode reward | -9       |
# | steps                   | 657      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 340      |
# | mean 100 episode reward | -9       |
# | steps                   | 677      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 350      |
# | mean 100 episode reward | -9       |
# | steps                   | 697      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 360      |
# | mean 100 episode reward | -9       |
# | steps                   | 717      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 370      |
# | mean 100 episode reward | -9       |
# | steps                   | 737      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 380      |
# | mean 100 episode reward | -9       |
# | steps                   | 757      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 390      |
# | mean 100 episode reward | -9       |
# | steps                   | 777      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 400      |
# | mean 100 episode reward | -9       |
# | steps                   | 797      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 410      |
# | mean 100 episode reward | -9       |
# | steps                   | 817      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 420      |
# | mean 100 episode reward | -9       |
# | steps                   | 837      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 430      |
# | mean 100 episode reward | -9       |
# | steps                   | 857      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 440      |
# | mean 100 episode reward | -9       |
# | steps                   | 877      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 450      |
# | mean 100 episode reward | -9       |
# | steps                   | 897      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 460      |
# | mean 100 episode reward | -9       |
# | steps                   | 917      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 470      |
# | mean 100 episode reward | -9       |
# | steps                   | 937      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 480      |
# | mean 100 episode reward | -9       |
# | steps                   | 957      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 490      |
# | mean 100 episode reward | -9       |
# | steps                   | 977      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 500      |
# | mean 100 episode reward | -9       |
# | steps                   | 997      |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 510      |
# | mean 100 episode reward | -9       |
# | steps                   | 1017     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 520      |
# | mean 100 episode reward | -9       |
# | steps                   | 1037     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 530      |
# | mean 100 episode reward | -9       |
# | steps                   | 1057     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 540      |
# | mean 100 episode reward | -9       |
# | steps                   | 1077     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 550      |
# | mean 100 episode reward | -9       |
# | steps                   | 1097     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 560      |
# | mean 100 episode reward | -9       |
# | steps                   | 1117     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 570      |
# | mean 100 episode reward | -9       |
# | steps                   | 1137     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 580      |
# | mean 100 episode reward | -9       |
# | steps                   | 1157     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 590      |
# | mean 100 episode reward | -9       |
# | steps                   | 1177     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 600      |
# | mean 100 episode reward | -9       |
# | steps                   | 1197     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 610      |
# | mean 100 episode reward | -9       |
# | steps                   | 1217     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 620      |
# | mean 100 episode reward | -9       |
# | steps                   | 1237     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 630      |
# | mean 100 episode reward | -9       |
# | steps                   | 1257     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 640      |
# | mean 100 episode reward | -9       |
# | steps                   | 1277     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 650      |
# | mean 100 episode reward | -9       |
# | steps                   | 1297     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 660      |
# | mean 100 episode reward | -9       |
# | steps                   | 1317     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 670      |
# | mean 100 episode reward | -9       |
# | steps                   | 1337     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 680      |
# | mean 100 episode reward | -9       |
# | steps                   | 1357     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 690      |
# | mean 100 episode reward | -9       |
# | steps                   | 1377     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 700      |
# | mean 100 episode reward | -9       |
# | steps                   | 1397     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 710      |
# | mean 100 episode reward | -9       |
# | steps                   | 1417     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 720      |
# | mean 100 episode reward | -9       |
# | steps                   | 1437     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 730      |
# | mean 100 episode reward | -9       |
# | steps                   | 1457     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 740      |
# | mean 100 episode reward | -9       |
# | steps                   | 1477     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 750      |
# | mean 100 episode reward | -9       |
# | steps                   | 1497     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 760      |
# | mean 100 episode reward | -9       |
# | steps                   | 1517     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 770      |
# | mean 100 episode reward | -9       |
# | steps                   | 1537     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 780      |
# | mean 100 episode reward | -9       |
# | steps                   | 1557     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 790      |
# | mean 100 episode reward | -9       |
# | steps                   | 1577     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 800      |
# | mean 100 episode reward | -9       |
# | steps                   | 1597     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 810      |
# | mean 100 episode reward | -9       |
# | steps                   | 1617     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 820      |
# | mean 100 episode reward | -9       |
# | steps                   | 1637     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 830      |
# | mean 100 episode reward | -9       |
# | steps                   | 1657     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 840      |
# | mean 100 episode reward | -9       |
# | steps                   | 1677     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 850      |
# | mean 100 episode reward | -9       |
# | steps                   | 1697     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 860      |
# | mean 100 episode reward | -9       |
# | steps                   | 1717     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 870      |
# | mean 100 episode reward | -9       |
# | steps                   | 1737     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 880      |
# | mean 100 episode reward | -9       |
# | steps                   | 1757     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 890      |
# | mean 100 episode reward | -9       |
# | steps                   | 1777     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 900      |
# | mean 100 episode reward | -9       |
# | steps                   | 1797     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 910      |
# | mean 100 episode reward | -9       |
# | steps                   | 1817     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 920      |
# | mean 100 episode reward | -9       |
# | steps                   | 1837     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 930      |
# | mean 100 episode reward | -9       |
# | steps                   | 1857     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 940      |
# | mean 100 episode reward | -9       |
# | steps                   | 1877     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 950      |
# | mean 100 episode reward | -9       |
# | steps                   | 1897     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 960      |
# | mean 100 episode reward | -9       |
# | steps                   | 1917     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 970      |
# | mean 100 episode reward | -9       |
# | steps                   | 1937     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 980      |
# | mean 100 episode reward | -9       |
# | steps                   | 1957     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 990      |
# | mean 100 episode reward | -9       |
# | steps                   | 1977     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 1000     |
# | mean 100 episode reward | -9       |
# | steps                   | 1997     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 1010     |
# | mean 100 episode reward | -9       |
# | steps                   | 2017     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 1020     |
# | mean 100 episode reward | -9       |
# | steps                   | 2037     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 79       |
# | episodes                | 1030     |
# | mean 100 episode reward | -9       |
# | steps                   | 2057     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 79       |
# | episodes                | 1040     |
# | mean 100 episode reward | -9       |
# | steps                   | 2077     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 79       |
# | episodes                | 1050     |
# | mean 100 episode reward | -9       |
# | steps                   | 2097     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 79       |
# | episodes                | 1060     |
# | mean 100 episode reward | -9       |
# | steps                   | 2117     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 79       |
# ...
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 65       |
# | episodes                | 1750     |
# | mean 100 episode reward | -9       |
# | steps                   | 3497     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 65       |
# | episodes                | 1760     |
# | mean 100 episode reward | -9       |
# | steps                   | 3517     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 65       |
# | episodes                | 1770     |
# | mean 100 episode reward | -9       |
# | steps                   | 3537     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 65       |
# | episodes                | 1780     |
# | mean 100 episode reward | -9       |
# | steps                   | 3557     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 1790     |
# | mean 100 episode reward | -9       |
# | steps                   | 3577     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 1800     |
# | mean 100 episode reward | -9       |
# | steps                   | 3597     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 1810     |
# | mean 100 episode reward | -9       |
# | steps                   | 3617     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 1820     |
# | mean 100 episode reward | -9       |
# | steps                   | 3637     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 1830     |
# | mean 100 episode reward | -9       |
# | steps                   | 3657     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 1840     |
# | mean 100 episode reward | -9       |
# | steps                   | 3677     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 1850     |
# | mean 100 episode reward | -9       |
# | steps                   | 3697     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 1860     |
# | mean 100 episode reward | -9       |
# | steps                   | 3717     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 1870     |
# | mean 100 episode reward | -9       |
# | steps                   | 3737     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 1880     |
# | mean 100 episode reward | -9       |
# | steps                   | 3757     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1890     |
# | mean 100 episode reward | -9       |
# | steps                   | 3777     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1900     |
# | mean 100 episode reward | -9       |
# | steps                   | 3797     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1910     |
# | mean 100 episode reward | -9       |
# | steps                   | 3817     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1920     |
# | mean 100 episode reward | -9       |
# | steps                   | 3837     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1930     |
# | mean 100 episode reward | -9       |
# | steps                   | 3857     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 1940     |
# | mean 100 episode reward | -9       |
# | steps                   | 3877     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 1950     |
# | mean 100 episode reward | -9       |
# | steps                   | 3897     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 1960     |
# | mean 100 episode reward | -9       |
# | steps                   | 3917     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 1970     |
# | mean 100 episode reward | -9       |
# | steps                   | 3937     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 1980     |
# | mean 100 episode reward | -9       |
# | steps                   | 3957     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 1990     |
# | mean 100 episode reward | -9       |
# | steps                   | 3977     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2000     |
# | mean 100 episode reward | -9       |
# | steps                   | 3997     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2010     |
# | mean 100 episode reward | -9       |
# | steps                   | 4017     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2020     |
# | mean 100 episode reward | -9       |
# | steps                   | 4037     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2030     |
# | mean 100 episode reward | -9       |
# | steps                   | 4057     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2040     |
# | mean 100 episode reward | -9       |
# | steps                   | 4077     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 59       |
# | episodes                | 2050     |
# | mean 100 episode reward | -9       |
# | steps                   | 4097     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 59       |
# | episodes                | 2060     |
# | mean 100 episode reward | -9       |
# | steps                   | 4117     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 59       |
# | episodes                | 2070     |
# | mean 100 episode reward | -9       |
# | steps                   | 4137     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 59       |
# | episodes                | 2080     |
# | mean 100 episode reward | -9       |
# | steps                   | 4157     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 59       |
# | episodes                | 2090     |
# | mean 100 episode reward | -9       |
# | steps                   | 4177     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# --------------------------------------
# | % time spent exploring  | 58       |
# | episodes                | 2100     |
# | mean 100 episode reward | -9       |
# | steps                   | 4197     |
# --------------------------------------
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante
# Suite pas croissante

# %%
import gym

# %%
from gym import spaces
